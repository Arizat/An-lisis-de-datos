# %% [markdown]
# #### Tarea5 Proyecto de análisis de datos
# #### **Leydi Tamara Ariza Cabrejo**
# #### Grupo: 202016908_66
# #### Tutor: Handry Orozco
# #### Universidad Nacional Abierta y a Distancia
# #### Escuela de ciencias Básicas tecnología e Ingeniería
# #### Curso: Análisis de datoss

# %% [markdown]
# #### Introducción
# En el desarrollo de  esta actividad se trabaja con el conjunto de datos del Titanic. El objetivo principal fue construir un modelo predictivo para determinar la probabilidad de supervivencia de los pasajeros basándonos en sus características, como edad, género, clase del pasajero, entre otras.
# Para lograrlo, primero se realizó un análisis Exploratorio de Datos (EDA) se examinó la distribución de las variables y las relaciones entre ellas, identificando patrones y posibles valores atípicos que pudieran influir en el modelo. Gráficas como la distribución de edades y la tasa de supervivencia según clase ayudaron a comprender mejor los datos.
# Posteriormente, se limpiaron y transformaron los datos, manejando valores faltantes, codificando variables categóricas y normalizando las variables numéricas para asegurar que los datos fueran adecuados para el modelo.
# Spara elegir las variables más relevantes para la predicción utilizando técnicas de selección de características. Esto optimizó el rendimiento del modelo al reducir la dimensionalidad.
# Por último, se separaron los datos en conjuntos de entrenamiento y prueba para evaluar de manera justa el desempeño del modelo.
# Para el modelo trabajado se seleccionó la Regresión Logística como modelo de aprendizaje supervisado, configurando sus parámetros para optimizar el desempeño.
#  Se analizaron métricas clave como precisión, recall, F1-score y se visualizó el desempeño mediante matrices de confusión y curvas ROC y se generaron gráficas que permitieron interpretar mejor los patrones y el impacto de las características en la supervivencia.

# %% [markdown]
# #### Modelo a usar: **Regresión Logistica**

# %%
# Importar librerias
import pandas as pd
import numpy as np

# %% [markdown]
# #### Importar dataset

# %%
data = pd.read_csv("Titanic-Dataset.csv")
#leer los datos
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S
# 15      0            248706  16.0000   NaN        S
# 16      1            382652  29.1250   NaN        Q
# 17      0            244373  13.0000   NaN        S
# 18      0            345763  18.0000   NaN        S
# 19      0              2649   7.2250   NaN        C

# %% [markdown]
# #### Análisis Exploratorio de Datos

# %%
# Visualizar las estadisticas de las variables
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex           Age  \
# count   891.000000  891.000000  891.000000  891.000000  8.910000e+02
# mean    446.000000    0.383838    2.308642    0.352413  2.232906e-16
# std     257.353842    0.486592    0.836071    0.477990  1.000562e+00
# min       1.000000    0.000000    1.000000    0.000000 -2.253155e+00
# 25%     223.500000    0.000000    2.000000    0.000000 -5.924806e-01
# 50%     446.000000    0.000000    3.000000    0.000000  0.000000e+00
# 75%     668.500000    1.000000    3.000000    1.000000  4.079260e-01
# max     891.000000    1.000000    3.000000    1.000000  3.870872e+00
#
#             SibSp       Parch          Fare
# count  891.000000  891.000000  8.910000e+02
# mean     0.523008    0.381594  3.987333e-18
# std      1.102743    0.806057  1.000562e+00
# min      0.000000    0.000000 -6.484217e-01
# 25%      0.000000    0.000000 -4.891482e-01
# 50%      0.000000    0.000000 -3.573909e-01
# 75%      1.000000    0.000000 -2.424635e-02
# max      8.000000    6.000000  9.667167e+00

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualizar la distribución de los datos de la variable Survived
sns.countplot(x='Survived', hue='Survived', data=data, palette='Greens', dodge=False, legend=False)
plt.title('Distribución de supervivientes')
plt.show()

# %% [markdown]
# La cantidad de individuos que no sobrevivieron es significativamente mayor que la cantidad de aquellos que sí lo hicieron. Existe un desbalance en las clases de la variable "Survived", lo que podría tener implicaciones en el análisis de modelos predictivos si esta variable fuera la variable objetivo.

# %%
# Seleccionamos solo las columnas numéricas
data_numeric = data.select_dtypes(include=['float64', 'int64'])

# Matriz de correlación solo para las columnas numéricas
plt.figure(figsize=(10, 8))
sns.heatmap(data_numeric.corr(), annot=True, cmap='YlGnBu')
plt.title('Matriz de Correlación')
plt.show()

# %%
# Ver distribuciones de variables numéricas
sns.histplot(data['Age'].dropna(), kde=True, color='green')
plt.title('Distribución de Edad')
plt.show()

# %% [markdown]
# #### Procesar los datos
# Incluye manejar valores faltantes, codificar variables categóricas y estandarizar o normalizar las variables según sea necesario.

# %%
# Tratamiento de valores faltantes
data['Age'] = data['Age'].fillna(data['Age'].mean())  # Rellenar con la media
data['Embarked'] = data['Embarked'].fillna(data['Embarked'].mode()[0])  # Rellenar con la moda

# %%
# Codificar las variables categóricas
data['Sex'] = data['Sex'].map({'male': 0, 'female': 1})
data = pd.get_dummies(data, columns=['Embarked'], drop_first=True)

# %%
# Normalización de las variables numéricas
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data[['Age', 'Fare']] = scaler.fit_transform(data[['Age', 'Fare']])

# %%
# Ver el resultado del preprocesamiento
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S
# 15      0            248706  16.0000   NaN        S
# 16      1            382652  29.1250   NaN        Q
# 17      0            244373  13.0000   NaN        S
# 18      0            345763  18.0000   NaN        S
# 19      0              2649   7.2250   NaN        C

# %% [markdown]
# #### Selección de características
# Aquí se identifican las variables más relevantes para entrenar el modelo. Se usa técnicas de selección de características como SelectKBest.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import SelectKBest, chi2

# Codificar las columnas categóricas
label_encoder = LabelEncoder()
X = X.apply(label_encoder.fit_transform)

# Seleccionar las 5 mejores características
selector = SelectKBest(chi2, k=5)
X_new = selector.fit_transform(X, y)

# %%
# Ver las características seleccionadas
selected_features = X.columns[selector.get_support()]
print("Características seleccionadas:", selected_features)
# Out:
# Características seleccionadas: Index(['Pclass', 'Sex', 'Age', 'Parch', 'Fare'], dtype='object')

# %% [markdown]
# #### División de Datos en Train y Test
# Dividimos el conjunto de datos en entrenamiento y prueba para evaluar el modelo

# %%
from sklearn.model_selection import train_test_split

# Dividir los datos
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)
print("El dataset ha sido dividido")
# Out:
# El dataset ha sido dividido

# %% [markdown]
# #### Entrenamiento del Modelo
# En este paso entrenamos el modelo de Regresión Logística y se ajustan los hiperparámetros

# %%
from sklearn.linear_model import LogisticRegression

# Crear el modelo
model = LogisticRegression()

# Entrenar el modelo
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ####  Evaluación del Desempeño del Modelo
# Evaluamos el modelo utilizando métricas como precisión, recall, F1-score, etc.

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

# Predecir en el conjunto de test
y_pred = model.predict(X_test)

# %%
# Evaluar el desempeño
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f'Accuracy: {accuracy:.2f}')
print(f'Recall: {recall:.2f}')
print(f'Precision: {precision:.2f}')
print(f'F1-Score: {f1:.2f}')
# Out:
# Accuracy: 0.77
# Recall: 0.62
# Precision: 0.78
# F1-Score: 0.69

# %% [markdown]
# #### Visualización de los Resultados
# Usaremos matrices de confusión y curvas ROC para visualizar el desempeño del modelo.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title('Matriz de Confusión')
plt.show()

# %%
# Curva ROC
fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.show()

# %%
# Distribución de edades por supervivencia
plt.figure(figsize=(10, 6))
sns.violinplot(x='Survived', y='Age', hue='Sex', data=data, split=True, palette='muted')
plt.title('Distribución de Edad por Supervivencia')
plt.xlabel('Supervivencia (0 = No, 1 = Sí)')
plt.ylabel('Edad')
plt.show()

# %%
# Supervivencia según la clase del pasajero
plt.figure(figsize=(10, 6))
sns.barplot(x='Pclass', y='Survived', data=data, hue='Pclass', palette='coolwarm', dodge=False, legend=False)
plt.title('Supervivencia por Clase de Pasajero')
plt.xlabel('Clase de Pasajero')
plt.ylabel('Tasa de Supervivencia')
plt.show()

# %% [markdown]
# #### Interpretación, Análisis y Documentación

# %% [markdown]
# Análisis de resultados: Después de obtener los resultados, se pueden interpretar las métricas para ver cómo se comporta el modelo en términos de precisión, recall y F1-score.
# Reflexiones: Identificar las características que tienen mayor impacto en la predicción de la supervivencia.
# Mejoras potenciales: Explorar otros modelos o ajustar los hiperparámetros para mejorar el desempeño.
